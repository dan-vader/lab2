# %% [markdown]
# ### 1. Azure Data Lake Storage Gen2 (ADLS)
# ![Azure Storage Account Overview](images/dls.png)

# %% [markdown]
# ### 2. Azure Key Vault
# ![Azure Key Vault Overview](images/key_vault.png)

# %% [markdown]
# ### 3. Azure Databricks Workspace
# ![Azure Databricks Overview](images/dbw.png)
